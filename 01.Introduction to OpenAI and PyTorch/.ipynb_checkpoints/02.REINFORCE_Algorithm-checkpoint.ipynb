# %%
from IPython.display import Image
img_path = "/Users/debnsuma/AWS/code/Reinforcement-Learning/img"

# %% [markdown]
# # Policy Search Algorithm

# %%
Image(f"{img_path}/img7.png")

# %% [markdown]
# # 1. Brute Force Methods

# %%
Image(f"{img_path}/img9.png")

# %% [markdown]
# # 2. Policy Gradient Methods

# %%
Image(f"{img_path}/img8.png")

# %% [markdown]
# # 3. Value Function Methods

# %%
Image(f"{img_path}/img10.png")

# %% [markdown]
# # Summary

# %%
Image(f"{img_path}/img6.png")

# %% [markdown]
# # Import packages

# %%
import numpy as np
import torch
import gym
from matplotlib import pyplot as plt

# %% [markdown]
# # OpenAI Gym's Cartpole Environment

# %%
Image(f"{img_path}/img11.png")

# %%
env = gym.make('CartPole-v0')
print('observation space:', env.observation_space)
print('action space:', env.action_space)
print('threshold: ', env.spec.reward_threshold)
# Out:
# observation space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# action space: Discrete(2)
# threshold:  195.0

# %% [markdown]
# # Model

# %% [markdown]
# We will build a neural network that serves as a policy network. The policy network will accept a state vectors as inputs, and it will produce a (discrete) probability distribution over the possible actions.

# %%
Image(f"{img_path}/img12.png")

# %%
obs_size = env.observation_space.shape[0] 
n_actions = env.action_space.n  
HIDDEN_SIZE = 256

model = torch.nn.Sequential(
             torch.nn.Linear(obs_size, HIDDEN_SIZE),
             torch.nn.ReLU(),
             torch.nn.Linear(HIDDEN_SIZE, n_actions),
             torch.nn.Softmax(dim=0)
     )

print (model)
# Out:
# Sequential(
#   (0): Linear(in_features=4, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=2, bias=True)
#   (3): Softmax(dim=0)
# )

# %% [markdown]
# # The REINFORCE training loop

# %%
learning_rate = 0.003
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

Horizon = 500
MAX_TRAJECTORIES = 500
gamma = 0.99
score = [] 

for trajectory in range(MAX_TRAJECTORIES):
    curr_state = env.reset()
    done = False
    transitions = [] 
    
    # Input to CNN  
    for t in range(Horizon):
        act_prob = model(torch.from_numpy(curr_state).float())
        action = np.random.choice(np.array([0,1]), p=act_prob.data.numpy())
        prev_state = curr_state
        curr_state, _, done, info = env.step(action) 
        transitions.append((prev_state, action, t+1)) 
        if done: 
            break
    score.append(len(transitions))
    reward_batch = torch.Tensor([r for (s,a,r) in transitions]).flip(dims=(0,)) 
    
    # Compute the expected return for each transaction 
    batch_Gvals =[]    
    for i in range(len(transitions)):
        new_Gval=0
        power=0
        for j in range(i,len(transitions)):
            new_Gval=new_Gval+((gamma**power)*reward_batch[j]).numpy()
            power+=1
        batch_Gvals.append(new_Gval)
        
    # Stores the expected returns for all the transactions of the current trajectory
    expected_returns_batch=torch.FloatTensor(batch_Gvals)     
    expected_returns_batch /= expected_returns_batch.max()

    state_batch = torch.Tensor([s for (s,a,r) in transitions]) 
    action_batch = torch.Tensor([a for (s,a,r) in transitions]) 

    pred_batch = model(state_batch) 
    prob_batch = pred_batch.gather(dim=1,index=action_batch.long().view(-1,1)).squeeze() 
    
    loss = - torch.sum(torch.log(prob_batch) * expected_returns_batch) 
    
    # Calculation of Loss and Backpropagation 
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if trajectory % 50 == 0 and trajectory>0:
            print('Trajectory {}\tAverage Score: {:.2f}'.format(trajectory, np.mean(score[-50:-1])))
# Out:
# Trajectory 50	Average Score: 31.10
# Trajectory 100	Average Score: 43.63
# Trajectory 150	Average Score: 52.84
# Trajectory 200	Average Score: 75.41
# Trajectory 250	Average Score: 107.84
# Trajectory 300	Average Score: 125.88
# Trajectory 350	Average Score: 166.41
# Trajectory 400	Average Score: 173.14
# Trajectory 450	Average Score: 165.49

# %% [markdown]
# # Plot the Scores

# %%
def running_mean(x):
    N=50
    kernel = np.ones(N)
    conv_len = x.shape[0]-N
    y = np.zeros(conv_len)
    for i in range(conv_len):
        y[i] = kernel @ x[i:i+N]
        y[i] /= N
    return y


score = np.array(score)
avg_score = running_mean(score)

plt.figure(figsize=(15,7))
plt.ylabel("Trajectory Duration",fontsize=12)
plt.xlabel("Training Epochs",fontsize=12)
plt.plot(score, color='gray' , linewidth=1)
plt.plot(avg_score, color='blue', linewidth=3)
plt.scatter(np.arange(score.shape[0]),score, color='green' , linewidth=0.3)

# %% [markdown]
# # Render Cartpole Environment

# %%
from IPython import display

# %%
def watch_agent():
    env = gym.make('CartPole-v0')
    state = env.reset()
    rewards = []
    img = plt.imshow(env.render(mode='rgb_array'))
    for t in range(2000):
        pred = model(torch.from_numpy(state).float())
        action = np.random.choice(np.array([0,1]), p=pred.data.numpy())

        img.set_data(env.render(mode='rgb_array')) 
        plt.axis('off')
        display.display(plt.gcf())
        display.clear_output(wait=True)

        state, reward, done, _ = env.step(action)
        rewards.append(reward)
        if done:
            print("Reward:", sum([r for r in rewards]))
            break 
    env.close()

watch_agent()
# Out:
# Reward: 200.0
